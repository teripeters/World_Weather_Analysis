# %%
# Create a practice set of random latitute and longitude combinations.

lats = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
lngs = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations.

for coordinate in coordinates:
    
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
from citipy import citipy

# %%
# Use the print() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# cockburn town tc
# gat ly
# parvatsar in
# punta arenas cl
# saint george bm

# %%
# Import the requests library.

import requests

# Import the API key.

from config import weather_api_key

# %%
# Start URL for Weather Map API Call.

url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5569f396e858755f53c66bae99463b7c

# %%
# Create an endpoint URL for a city.

city_url = url + "&q=" + "Boston"

print(city_url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5569f396e858755f53c66bae99463b7c&q=Boston

# %%
# Make a "Get" request for the city weather.

city_weather = requests.get(city_url)

city_weather
# Out:
# <Response [200]>

# %%
city_weather.status_code
# Out:
# 200

# %%
# Create an endpoint URL for a city.

city_url = url +"&q=" + "Bston"

city_weather = requests.get(city_url)

city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.

city_url = url +"&q=" + "Honolulu"

city_weather = requests.get(city_url)

city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the "Get" request.

city_weather.text
# Out:
# '{"coord":{"lon":-157.8583,"lat":21.3069},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}],"base":"stations","main":{"temp":76.51,"feels_like":77.25,"temp_min":74.28,"temp_max":78.62,"pressure":1015,"humidity":72},"visibility":10000,"wind":{"speed":16.11,"deg":60},"clouds":{"all":40},"dt":1655967175,"sys":{"type":1,"id":7878,"country":"US","sunrise":1655913034,"sunset":1655961380},"timezone":-36000,"id":5856195,"name":"Honolulu","cod":200}'

# %%
# Get the JSON text of the "Get" request.

city_weather.json()
# Out:
# {'coord': {'lon': -157.8583, 'lat': 21.3069},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 76.51,
#   'feels_like': 77.25,
#   'temp_min': 74.28,
#   'temp_max': 78.62,
#   'pressure': 1015,
#   'humidity': 72},
#  'visibility': 10000,
#  'wind': {'speed': 16.11, 'deg': 60},
#  'clouds': {'all': 40},
#  'dt': 1655967175,
#  'sys': {'type': 1,
#   'id': 7878,
#   'country': 'US',
#   'sunrise': 1655913034,
#   'sunset': 1655961380},
#  'timezone': -36000,
#  'id': 5856195,
#  'name': 'Honolulu',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.

city_url = url + "&q=" + "Boston"

city_weather = requests.get(city_url)

if city_weather.status_code == 200:
    
    print(f"City weather found.")
    
else:
    
    print(f"City weather not found.")
# Out:
# City weather found.

# %%
# Create an endpoint URL for a city.

city_url = url + "&q=" + "Boston"

city_weather = requests.get(city_url)

city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 58.73,
#   'feels_like': 58.77,
#   'temp_min': 55.71,
#   'temp_max': 61.09,
#   'pressure': 1017,
#   'humidity': 95},
#  'visibility': 10000,
#  'wind': {'speed': 5.75, 'deg': 80},
#  'clouds': {'all': 40},
#  'dt': 1655967346,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1655975278,
#   'sunset': 1656030291},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.

boston_data = city_weather.json()

# %%
boston_data["sys"]["country"]
# Out:
# 'US'

# %%
boston_data["dt"]
# Out:
# 1655967346

# %%
lat = boston_data["coord"]["lat"]

lng = boston_data["coord"]["lon"]

max_temp = boston_data["main"]["temp_max"]

humidity = boston_data["main"]["humidity"]

clouds = boston_data["clouds"]["all"]

wind = boston_data["wind"]["speed"]

print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 61.09 95 40 5.75

# %%
# Import the datetime module from the datetime library.

from datetime import datetime

# Get the date from the JSON file.

date = boston_data["dt"]

# convert the UTC date to a date format with. year, month, day, hours, minutes, and seconds.

datetime.utcfromtimestamp(date).strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2022-06-23 06:55:46'

# %%
# Import the time model.

import time

# Get today's date in seconds.

today = time.strftime("%x")

today
# Out:
# '06/23/22'
